# %%
"""
Landon Buell
Machine Learning 
2nd Class
12 Feb 2020
"""

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Guest Speaker: John Donaghy
# Github page: chapmanlab.github.io/ML
# 4-Day Boot camp for ML at LB & L
#
# #### Linear Regression on non- linear systems
#
# $ y = a_0 + a_1x_1 + a_2x_2^2 + ... $
#
# # Non-Linear Regression - Gaussian Processses
#
#    1. Posterior distribution over all function
#    2. Incorporate domain knowledge ( allows for
#    3. Interpolates data sets w/ confidence intervals
#    4. We can tell how certain a Gaussian process is - Does it know what it knows

# %% [markdown]
# ### Non- Linearity
#     1. Introduce a keneral function for weights
#     2. Requires large amounts of RAM
#     3.

# %%
npts = 10

# create data & remove point 
xtrain = np.arange(0,10,1)
xtrain_red = np.delete(xtrain,4).reshape(-1,1)
ytrain = np.sin(xtrain)
ytrain_red = np.sin(xtrain)
