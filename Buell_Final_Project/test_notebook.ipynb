# %%
"""
Landon Buell
21 April 2020
"""

import numpy as np

# total layers (hidden + input + output)
N_layers = 10

for l in range (N_layers-1,0,-1):
    print("Layer:",l)
# Out:
# Layer: 9
# Layer: 8
# Layer: 7
# Layer: 6
# Layer: 5
# Layer: 4
# Layer: 3
# Layer: 2
# Layer: 1
