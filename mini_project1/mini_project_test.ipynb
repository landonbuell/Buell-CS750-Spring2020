# %%
"""
Landon Buell
CS 750.01
Mini project test
3 March 2020
"""

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load in Landscape data features 
landscape_data = pd.read_csv('miniproject_landscape.csv',delimiter=',',
                            header=0,index_col=False)
#print(landscape_data.shape)
landscape_data.head(-10)
# Out:
#        cellid       long        lat       bio1       bio2       bio3  \
# 0           1 -74.979167  46.979167   1.972500  10.513667  24.274258
# 1           2 -74.937500  46.979167   1.833333  10.466000  24.191013
# 2           3 -74.895833  46.979167   1.790833  10.385667  23.998675
# 3           4 -74.854167  46.979167   1.869167  10.429666  24.044786
# 4           5 -74.812500  46.979167   1.738167  10.633667  24.355627
# ...       ...        ...        ...        ...        ...        ...
# 21782   21783 -74.645833  40.020833  11.925333  12.052667  33.159092
# 21783   21784 -74.604167  40.020833  11.923667  11.798000  32.721322
# 21784   21785 -74.562500  40.020833  11.936500  11.839666  32.815040
# 21785   21786 -74.520833  40.020833  11.926667  11.983333  33.121430
# 21786   21787 -74.479167  40.020833  11.888333  11.803334  32.841774
#
#               bio4       bio5    bio6       bio7  ...      bio10      bio11  \
# ...

# %%
# Load in synthetic training data
synth_train = pd.read_csv('miniproject_synthetic_train.csv',delimiter=',',
                          header=0,index_col=False)
print(synth_train.shape)
print(synth_train.head(-10))
# Out:
# (3204, 2)
#       cellid  freq
# 0      20284     1
# 1      15844     1
# 2       4820     1
# 3      18635     1
# 4       3987     1
# ...      ...   ...
# 3189   16234     3
# 3190   17105     4
# 3191   17484     2
# 3192   13781     1
# 3193    2521     1
#
# [3194 rows x 2 columns]
